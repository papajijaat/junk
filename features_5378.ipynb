# %%
import pandas as pd

# %%
#data_xls = pd.read_excel('./features_15850.xlsx', 'Sheet1', index_col=None)

# %%
#data_xls.to_csv('features_15850.csv', encoding='utf-8', index=False)

# %%
df = pd.read_csv('./features_5378.csv')

# %%
df = df.values

# %%
df = df / df.max(axis=0)

# %%
#

# %%
print(df.shape)
# Out:
# (179, 3)

# %%
df
# Out:
# array([[0.046875  , 0.92      , 0.        ],
#        [0.078125  , 0.84      , 0.11764706],
#        [0.078125  , 0.84      , 0.05882353],
#        [0.0390625 , 0.84      , 0.        ],
#        [0.34375   , 0.56      , 0.        ],
#        [0.078125  , 0.84      , 0.05882353],
#        [0.0390625 , 0.8       , 0.        ],
#        [0.0390625 , 0.88      , 0.        ],
#        [0.28125   , 0.56      , 0.        ],
#        [0.078125  , 0.8       , 0.        ],
#        [0.0859375 , 0.36      , 0.        ],
#        [0.0078125 , 0.6       , 0.        ],
#        [0.015625  , 0.52      , 0.        ],
#        [0.015625  , 0.4       , 0.05882353],
#        [0.015625  , 0.4       , 0.05882353],
#        [0.0390625 , 0.4       , 0.11764706],
#        [0.015625  , 0.4       , 0.05882353],
#        [0.0390625 , 0.4       , 0.11764706],
#        [0.0234375 , 0.4       , 0.05882353],
#        [0.0859375 , 0.4       , 0.11764706],
#        [0.0625    , 0.4       , 0.05882353],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
ax.scatter(df[:53, 0], df[:53, 1], df[:53, 2],color='black')
ax.scatter(df[54, 0], df[54, 1], df[54, 2],color='red')
ax.scatter(df[55:60, 0], df[55:60, 1], df[55:60, 2],color='black')
ax.scatter(df[61, 0], df[61, 1], df[61, 2],color='red')
ax.scatter(df[62:68, 0], df[62:68, 1], df[62:68, 2],color='black')
ax.scatter(df[69, 0], df[69, 1], df[69, 2],color='red')
ax.scatter(df[70:78, 0], df[70:78, 1], df[70:78, 2],color='black')
ax.scatter(df[79, 0], df[79, 1], df[79, 2],color='red')
ax.scatter(df[80:86, 0], df[80:86, 1], df[80:86, 2],color='black')
ax.scatter(df[87, 0], df[87, 1], df[87, 2],color='red')
ax.scatter(df[88:96, 0], df[88:96, 1], df[88:96, 2],color='black')
ax.scatter(df[97, 0], df[97, 1], df[97, 2],color='red')
ax.scatter(df[98:101, 0], df[98:101, 1], df[98:101, 2],color='black')
ax.scatter(df[102, 0], df[102, 1], df[102, 2],color='red')
ax.scatter(df[103:118, 0], df[103:118, 1], df[103:118, 2],color='black')
ax.scatter(df[119, 0], df[119, 1], df[119, 2],color='red')
ax.scatter(df[120:125, 0], df[120:125, 1], df[120:125, 2],color='black')
ax.scatter(df[126, 0], df[126, 1], df[126, 2],color='red')
ax.scatter(df[127:133, 0], df[127:133, 1], df[127:133, 2],color='black')
ax.scatter(df[134, 0], df[134, 1], df[134, 2],color='red')
ax.scatter(df[135, 0], df[135, 1], df[135, 2],color='black')
ax.scatter(df[136, 0], df[136, 1], df[136, 2],color='red')
ax.scatter(df[137, 0], df[137, 1], df[137, 2],color='black')
ax.scatter(df[138, 0], df[138, 1], df[138, 2],color='red')
ax.scatter(df[139, 0], df[139, 1], df[139, 2],color='black')
ax.scatter(df[140, 0], df[140, 1], df[140, 2],color='red')
ax.scatter(df[141:147, 0], df[141:147, 1], df[141:147, 2],color='black')
ax.scatter(df[148, 0], df[148, 1], df[148, 2],color='red')
ax.scatter(df[149:155, 0], df[149:155, 1], df[149:155, 2],color='black')
ax.scatter(df[156, 0], df[156, 1], df[156, 2],color='red')
ax.scatter(df[157:158, 0], df[157:158, 1], df[157:158, 2],color='black')
ax.scatter(df[159, 0], df[159, 1], df[159, 2],color='red')
ax.scatter(df[160:178, 0], df[160:178, 1], df[160:178, 2],color='black')


ax.set_xlabel('Connectivity')
ax.set_ylabel('Topsortlevel')
ax.set_zlabel('Site')

ax.dist = 12
